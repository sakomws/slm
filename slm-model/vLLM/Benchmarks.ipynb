# %% [markdown]
# # Install guidellm

# %%
#eventually use 0.3 when it is released
# %pip install --quiet git+https://github.com/vllm-project/guidellm.git@1261fe8
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Time for the benchmark
# Running this next cell will create a synchronous-benchmarks.csv file in the directory.  You should be able to click on it in the listing on the left.
#
# If you have a spreadsheet program on your laptop, right click on the file and "Download" it, then open it locally.  We'll explore it in the next cell.
#
# This benchmark should only take 30 seconds to run because we are only doing a single request at a time ("synchronous").  This will give you metrics similar to a single user using the endpoint.

# %%
# !guidellm benchmark \
  --target "http://localhost:8080" \
  --rate-type synchronous \
  --max-seconds 30 \
  --data "prompt_tokens=125,output_tokens=56" \
  --output-path=synchronous_benchmarks.csv
# Out:
# Creating backend...
# Backend openai_http connected to http://localhost:8080 for model
# TinyLlama/TinyLlama-1.1B-Chat-v1.0.
# Creating request loader...
# Created loader with 1000 unique requests from
# prompt_tokens=129,output_tokens=56.
#
#
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮
# │ [2… syn… (r… Req:    0.0 req/s,    0.00s Lat,     1.0 Conc,       0 Comp,  … │
# │              Tok:    0.0 gen/s,    0.0 tot/s,   0.0ms TTFT,    0.0ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮--:-- ]
# │ [2… syn… (r… Req:    0.0 req/s,    0.00s Lat,     1.0 Conc,       0 Comp,  … │
# │              Tok:    0.0 gen/s,    0.0 tot/s,   0.0ms TTFT,    0.0ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮--:-- ]
# │ [2… syn… (r… Req:    1.7 req/s,    0.47s Lat,     1.0 Conc,       1 Comp,  … │
# │              Tok:   93.3 gen/s,  308.2 tot/s,  62.7ms TTFT,    7.3ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮< 0:00:30 ]
# │ [2… syn… (r… Req:    1.7 req/s,    0.47s Lat,     1.0 Conc,       1 Comp,  … │
# │              Tok:   93.3 gen/s,  308.2 tot/s,  62.7ms TTFT,    7.3ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮< 0:00:30 ]
# │ [2… syn… (r… Req:    2.0 req/s,    0.45s Lat,     1.0 Conc,       2 Comp,  … │
# │              Tok:  109.3 gen/s,  361.0 tot/s,  39.2ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:01 < 0:00:29 ]
# │ [2… syn… (r… Req:    2.1 req/s,    0.44s Lat,     1.0 Conc,       3 Comp,  … │
# │              Tok:  115.7 gen/s,  382.2 tot/s,  31.5ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:01 < 0:00:29 ]
# │ [2… syn… (r… Req:    2.1 req/s,    0.44s Lat,     1.0 Conc,       3 Comp,  … │
# │              Tok:  115.7 gen/s,  382.2 tot/s,  31.5ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:01 < 0:00:29 ]
# │ [2… syn… (r… Req:    2.1 req/s,    0.44s Lat,     1.0 Conc,       4 Comp,  … │
# │              Tok:  119.4 gen/s,  394.3 tot/s,  27.7ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:02 < 0:00:29 ]
# │ [2… syn… (r… Req:    2.1 req/s,    0.44s Lat,     1.0 Conc,       4 Comp,  … │
# │              Tok:  119.4 gen/s,  394.3 tot/s,  27.7ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:02 < 0:00:29 ]
# │ [2… syn… (r… Req:    2.2 req/s,    0.43s Lat,     1.0 Conc,       5 Comp,  … │
# │              Tok:  121.8 gen/s,  402.2 tot/s,  25.5ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:02 < 0:00:28 ]
# │ [2… syn… (r… Req:    2.2 req/s,    0.43s Lat,     1.0 Conc,       6 Comp,  … │
# │              Tok:  123.2 gen/s,  407.1 tot/s,  24.0ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:02 < 0:00:28 ]
# │ [2… syn… (r… Req:    2.2 req/s,    0.43s Lat,     1.0 Conc,       6 Comp,  … │
# │              Tok:  123.2 gen/s,  407.1 tot/s,  24.0ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:03 < 0:00:28 ]
# │ [2… syn… (r… Req:    2.2 req/s,    0.43s Lat,     1.0 Conc,       7 Comp,  … │
# │              Tok:  124.3 gen/s,  410.5 tot/s,  22.9ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:03 < 0:00:27 ]
# │ [2… syn… (r… Req:    2.2 req/s,    0.43s Lat,     1.0 Conc,       7 Comp,  … │
# │              Tok:  124.3 gen/s,  410.5 tot/s,  22.9ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:03 < 0:00:27 ]
# │ [2… syn… (r… Req:    2.2 req/s,    0.43s Lat,     1.0 Conc,       8 Comp,  … │
# │              Tok:  125.3 gen/s,  413.8 tot/s,  22.1ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:03 < 0:00:27 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,       9 Comp,  … │
# │              Tok:  126.0 gen/s,  416.4 tot/s,  21.5ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:04 < 0:00:27 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,       9 Comp,  … │
# │              Tok:  126.0 gen/s,  416.4 tot/s,  21.5ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:04 < 0:00:27 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      10 Comp,  … │
# │              Tok:  126.6 gen/s,  418.2 tot/s,  21.0ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:04 < 0:00:26 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      10 Comp,  … │
# │              Tok:  126.6 gen/s,  418.2 tot/s,  21.0ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:04 < 0:00:26 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      11 Comp,  … │
# │              Tok:  127.1 gen/s,  419.7 tot/s,  20.6ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:05 < 0:00:26 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      12 Comp,  … │
# │              Tok:  127.4 gen/s,  420.8 tot/s,  20.3ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:05 < 0:00:25 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      12 Comp,  … │
# │              Tok:  127.4 gen/s,  420.8 tot/s,  20.3ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:05 < 0:00:25 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      13 Comp,  … │
# │              Tok:  127.7 gen/s,  421.7 tot/s,  20.0ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:05 < 0:00:25 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      13 Comp,  … │
# │              Tok:  127.7 gen/s,  421.7 tot/s,  20.0ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:06 < 0:00:25 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      14 Comp,  … │
# │              Tok:  127.9 gen/s,  422.5 tot/s,  19.7ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:06 < 0:00:24 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      15 Comp,  … │
# │              Tok:  128.1 gen/s,  423.3 tot/s,  19.5ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:06 < 0:00:24 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      15 Comp,  … │
# │              Tok:  128.1 gen/s,  423.3 tot/s,  19.5ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:06 < 0:00:24 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      16 Comp,  … │
# │              Tok:  128.3 gen/s,  424.0 tot/s,  19.3ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:07 < 0:00:24 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      16 Comp,  … │
# │              Tok:  128.3 gen/s,  424.0 tot/s,  19.3ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:07 < 0:00:24 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      17 Comp,  … │
# │              Tok:  128.5 gen/s,  424.5 tot/s,  19.2ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:07 < 0:00:23 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      18 Comp,  … │
# │              Tok:  128.7 gen/s,  425.1 tot/s,  19.0ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:07 < 0:00:23 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      18 Comp,  … │
# │              Tok:  128.7 gen/s,  425.1 tot/s,  19.0ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:08 < 0:00:23 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      19 Comp,  … │
# │              Tok:  128.8 gen/s,  425.7 tot/s,  18.9ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:08 < 0:00:22 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      19 Comp,  … │
# │              Tok:  128.8 gen/s,  425.7 tot/s,  18.9ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:08 < 0:00:22 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      20 Comp,  … │
# │              Tok:  129.0 gen/s,  426.2 tot/s,  18.8ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:08 < 0:00:22 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      21 Comp,  … │
# │              Tok:  129.1 gen/s,  426.5 tot/s,  18.7ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:09 < 0:00:21 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      21 Comp,  … │
# │              Tok:  129.1 gen/s,  426.5 tot/s,  18.7ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:09 < 0:00:21 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      22 Comp,  … │
# │              Tok:  129.2 gen/s,  426.9 tot/s,  18.6ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:09 < 0:00:21 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      22 Comp,  … │
# │              Tok:  129.2 gen/s,  426.9 tot/s,  18.6ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:09 < 0:00:21 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      23 Comp,  … │
# │              Tok:  129.3 gen/s,  427.3 tot/s,  18.5ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:10 < 0:00:21 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      23 Comp,  … │
# │              Tok:  129.3 gen/s,  427.3 tot/s,  18.5ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:10 < 0:00:21 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      24 Comp,  … │
# │              Tok:  129.4 gen/s,  427.5 tot/s,  18.4ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:10 < 0:00:20 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      25 Comp,  … │
# │              Tok:  129.5 gen/s,  427.7 tot/s,  18.3ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:10 < 0:00:20 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      25 Comp,  … │
# │              Tok:  129.5 gen/s,  427.7 tot/s,  18.3ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:11 < 0:00:20 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      26 Comp,  … │
# │              Tok:  129.5 gen/s,  427.8 tot/s,  18.3ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:11 < 0:00:19 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      26 Comp,  … │
# │              Tok:  129.5 gen/s,  427.8 tot/s,  18.3ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:11 < 0:00:19 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      27 Comp,  … │
# │              Tok:  129.5 gen/s,  428.0 tot/s,  18.2ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:11 < 0:00:19 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      28 Comp,  … │
# │              Tok:  129.6 gen/s,  428.0 tot/s,  18.2ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:12 < 0:00:18 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      28 Comp,  … │
# │              Tok:  129.6 gen/s,  428.0 tot/s,  18.2ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:12 < 0:00:18 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      29 Comp,  … │
# │              Tok:  129.6 gen/s,  428.1 tot/s,  18.1ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:12 < 0:00:18 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      29 Comp,  … │
# │              Tok:  129.6 gen/s,  428.1 tot/s,  18.1ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:12 < 0:00:18 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      30 Comp,  … │
# │              Tok:  129.7 gen/s,  428.4 tot/s,  18.1ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:13 < 0:00:18 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      31 Comp,  … │
# │              Tok:  129.7 gen/s,  428.4 tot/s,  18.0ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:13 < 0:00:17 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      31 Comp,  … │
# │              Tok:  129.7 gen/s,  428.4 tot/s,  18.0ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:13 < 0:00:17 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      32 Comp,  … │
# │              Tok:  129.7 gen/s,  428.6 tot/s,  18.0ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:13 < 0:00:17 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      32 Comp,  … │
# │              Tok:  129.7 gen/s,  428.6 tot/s,  18.0ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:14 < 0:00:17 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      33 Comp,  … │
# │              Tok:  129.8 gen/s,  428.8 tot/s,  18.0ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:14 < 0:00:16 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      34 Comp,  … │
# │              Tok:  129.8 gen/s,  428.9 tot/s,  17.9ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:14 < 0:00:16 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      34 Comp,  … │
# │              Tok:  129.8 gen/s,  428.9 tot/s,  17.9ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:14 < 0:00:16 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      35 Comp,  … │
# │              Tok:  129.8 gen/s,  428.9 tot/s,  17.9ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:15 < 0:00:15 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      35 Comp,  … │
# │              Tok:  129.8 gen/s,  428.9 tot/s,  17.9ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:15 < 0:00:15 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      36 Comp,  … │
# │              Tok:  129.8 gen/s,  429.0 tot/s,  17.9ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:15 < 0:00:15 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      36 Comp,  … │
# │              Tok:  129.8 gen/s,  429.0 tot/s,  17.9ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:15 < 0:00:15 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      37 Comp,  … │
# │              Tok:  129.9 gen/s,  429.1 tot/s,  17.8ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:16 < 0:00:15 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      38 Comp,  … │
# │              Tok:  129.9 gen/s,  429.2 tot/s,  17.8ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:16 < 0:00:14 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      38 Comp,  … │
# │              Tok:  129.9 gen/s,  429.2 tot/s,  17.8ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:16 < 0:00:14 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      39 Comp,  … │
# │              Tok:  129.9 gen/s,  429.3 tot/s,  17.8ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:16 < 0:00:14 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      39 Comp,  … │
# │              Tok:  129.9 gen/s,  429.3 tot/s,  17.8ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:17 < 0:00:14 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      40 Comp,  … │
# │              Tok:  130.0 gen/s,  429.4 tot/s,  17.8ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:17 < 0:00:13 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      41 Comp,  … │
# │              Tok:  130.0 gen/s,  429.5 tot/s,  17.7ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:17 < 0:00:13 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      41 Comp,  … │
# │              Tok:  130.0 gen/s,  429.5 tot/s,  17.7ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:17 < 0:00:13 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      42 Comp,  … │
# │              Tok:  130.0 gen/s,  429.6 tot/s,  17.7ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:18 < 0:00:12 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      42 Comp,  … │
# │              Tok:  130.0 gen/s,  429.6 tot/s,  17.7ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:18 < 0:00:12 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      43 Comp,  … │
# │              Tok:  130.1 gen/s,  429.8 tot/s,  17.7ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:18 < 0:00:12 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      44 Comp,  … │
# │              Tok:  130.1 gen/s,  429.8 tot/s,  17.7ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:18 < 0:00:12 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      44 Comp,  … │
# │              Tok:  130.1 gen/s,  429.8 tot/s,  17.7ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:19 < 0:00:12 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      45 Comp,  … │
# │              Tok:  130.1 gen/s,  429.9 tot/s,  17.6ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:19 < 0:00:11 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      45 Comp,  … │
# │              Tok:  130.1 gen/s,  429.9 tot/s,  17.6ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:19 < 0:00:11 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      46 Comp,  … │
# │              Tok:  130.2 gen/s,  430.1 tot/s,  17.6ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:19 < 0:00:11 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      47 Comp,  … │
# │              Tok:  130.2 gen/s,  430.2 tot/s,  17.6ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:20 < 0:00:10 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      47 Comp,  … │
# │              Tok:  130.2 gen/s,  430.2 tot/s,  17.6ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:20 < 0:00:10 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      48 Comp,  … │
# │              Tok:  130.3 gen/s,  430.4 tot/s,  17.6ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:20 < 0:00:10 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      48 Comp,  … │
# │              Tok:  130.3 gen/s,  430.4 tot/s,  17.6ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:21 < 0:00:10 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      49 Comp,  … │
# │              Tok:  130.3 gen/s,  430.4 tot/s,  17.5ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:21 < 0:00:09 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      50 Comp,  … │
# │              Tok:  130.3 gen/s,  430.5 tot/s,  17.5ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:21 < 0:00:09 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      50 Comp,  … │
# │              Tok:  130.3 gen/s,  430.5 tot/s,  17.5ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:21 < 0:00:09 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      51 Comp,  … │
# │              Tok:  130.3 gen/s,  430.6 tot/s,  17.5ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:22 < 0:00:09 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      51 Comp,  … │
# │              Tok:  130.3 gen/s,  430.6 tot/s,  17.5ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:22 < 0:00:09 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      52 Comp,  … │
# │              Tok:  130.3 gen/s,  430.6 tot/s,  17.5ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:22 < 0:00:08 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      53 Comp,  … │
# │              Tok:  130.3 gen/s,  430.6 tot/s,  17.5ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:22 < 0:00:08 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      53 Comp,  … │
# │              Tok:  130.3 gen/s,  430.6 tot/s,  17.5ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:23 < 0:00:08 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      54 Comp,  … │
# │              Tok:  130.3 gen/s,  430.6 tot/s,  17.5ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:23 < 0:00:07 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      54 Comp,  … │
# │              Tok:  130.3 gen/s,  430.6 tot/s,  17.5ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:23 < 0:00:07 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      55 Comp,  … │
# │              Tok:  130.4 gen/s,  430.7 tot/s,  17.4ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:23 < 0:00:07 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      55 Comp,  … │
# │              Tok:  130.4 gen/s,  430.7 tot/s,  17.4ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:24 < 0:00:07 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      56 Comp,  … │
# │              Tok:  130.4 gen/s,  430.7 tot/s,  17.4ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:24 < 0:00:06 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      57 Comp,  … │
# │              Tok:  130.4 gen/s,  430.8 tot/s,  17.4ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:24 < 0:00:06 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      57 Comp,  … │
# │              Tok:  130.4 gen/s,  430.8 tot/s,  17.4ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:24 < 0:00:06 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      58 Comp,  … │
# │              Tok:  130.4 gen/s,  430.8 tot/s,  17.4ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:25 < 0:00:06 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      58 Comp,  … │
# │              Tok:  130.4 gen/s,  430.8 tot/s,  17.4ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:25 < 0:00:06 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      59 Comp,  … │
# │              Tok:  130.4 gen/s,  430.9 tot/s,  17.4ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:25 < 0:00:05 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      60 Comp,  … │
# │              Tok:  130.5 gen/s,  431.0 tot/s,  17.4ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:25 < 0:00:05 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      60 Comp,  … │
# │              Tok:  130.5 gen/s,  431.0 tot/s,  17.4ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:26 < 0:00:05 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      61 Comp,  … │
# │              Tok:  130.5 gen/s,  431.1 tot/s,  17.4ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:26 < 0:00:04 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      61 Comp,  … │
# │              Tok:  130.5 gen/s,  431.1 tot/s,  17.4ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:26 < 0:00:04 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      62 Comp,  … │
# │              Tok:  130.5 gen/s,  431.2 tot/s,  17.3ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:26 < 0:00:04 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      63 Comp,  … │
# │              Tok:  130.5 gen/s,  431.2 tot/s,  17.3ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:27 < 0:00:04 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      63 Comp,  … │
# │              Tok:  130.5 gen/s,  431.2 tot/s,  17.3ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:27 < 0:00:04 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      64 Comp,  … │
# │              Tok:  130.6 gen/s,  431.3 tot/s,  17.3ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:27 < 0:00:03 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      64 Comp,  … │
# │              Tok:  130.6 gen/s,  431.3 tot/s,  17.3ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:27 < 0:00:03 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      65 Comp,  … │
# │              Tok:  130.6 gen/s,  431.4 tot/s,  17.3ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:28 < 0:00:03 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      66 Comp,  … │
# │              Tok:  130.6 gen/s,  431.4 tot/s,  17.3ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:28 < 0:00:02 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      66 Comp,  … │
# │              Tok:  130.6 gen/s,  431.4 tot/s,  17.3ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:28 < 0:00:02 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      67 Comp,  … │
# │              Tok:  130.6 gen/s,  431.5 tot/s,  17.3ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:28 < 0:00:02 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      67 Comp,  … │
# │              Tok:  130.6 gen/s,  431.5 tot/s,  17.3ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:29 < 0:00:02 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      68 Comp,  … │
# │              Tok:  130.6 gen/s,  431.6 tot/s,  17.3ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:29 < 0:00:01 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      69 Comp,  … │
# │              Tok:  130.7 gen/s,  431.6 tot/s,  17.3ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮< 0:00:01 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      69 Comp,  … │
# │              Tok:  130.7 gen/s,  431.6 tot/s,  17.3ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮< 0:00:01 ]
# │ [2… syn… (r… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      70 Comp,  … │
# │              Tok:  130.7 gen/s,  431.7 tot/s,  17.3ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮< 0:00:01 ]
# │ [2… syn… (c… Req:    2.3 req/s,    0.43s Lat,     1.0 Conc,      70 Comp,  … │
# │              Tok:  131.2 gen/s,  434.0 tot/s,  17.3ms TTFT,    7.4ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# Generating... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ (1/1) [ 0:00:30 < 0:00:00 ]
#
#
# Benchmarks Metadata:
#     Run id:824fd90f-1cae-46fb-ac06-849f9288bcc3
#     Duration:30.2 seconds
#     Profile:type=synchronous, strategies=['synchronous']
#     Args:max_number=None, max_duration=30.0, warmup_number=None,
#     warmup_duration=None, cooldown_number=None, cooldown_duration=None
#     Worker:type_='generative_requests_worker' backend_type='openai_http'
#     backend_target='http://localhost:8080'
#     backend_model='TinyLlama/TinyLlama-1.1B-Chat-v1.0'
#     backend_info={'max_output_tokens': 16384, 'timeout': 300, 'http2': True,
#     'follow_redirects': True, 'headers': {}, 'text_completions_path':
#     '/v1/completions', 'chat_completions_path': '/v1/chat/completions'}
#     Request Loader:type_='generative_request_loader'
#     data='prompt_tokens=129,output_tokens=56' data_args=None
#     processor='TinyLlama/TinyLlama-1.1B-Chat-v1.0' processor_args=None
#     Extras:None
#
#
# Benchmarks Info:
# ================================================================================
# =====================================================================
# Metadata                                    |||| Requests Made  ||| Prompt
# Tok/Req ||| Output Tok/Req  ||| Prompt Tok Total  ||| Output Tok Total  ||
#   Benchmark| Start Time| End Time| Duration (s)|  Comp|  Inc|  Err|  Comp|
# Inc| Err|  Comp|   Inc|  Err|   Comp|   Inc|   Err|   Comp|   Inc|   Err
# -----------|-----------|---------|-------------|------|-----|-----|------|------
# |----|------|------|-----|-------|------|------|-------|------|------
# synchronous|   21:15:56| 21:16:26|         30.0|    70|    1|    0| 130.2|
# 129.0| 0.0|  56.0|  16.0|  0.0|   9114|   129|     0|   3920|    16|     0
# ================================================================================
# =====================================================================
#
#
# Benchmarks Stats:
# ================================================================================
# ===============================================================
# Metadata   | Request Stats         || Out Tok/sec| Tot Tok/sec| Req Latency
# (sec)  ||| TTFT (ms)       ||| ITL (ms)       ||| TPOT (ms)      ||
#   Benchmark| Per Second| Concurrency|        mean|        mean|  mean|  median|
# p99| mean| median|  p99| mean| median| p99| mean| median| p99
# -----------|-----------|------------|------------|------------|------|--------|-
# -----|-----|-------|-----|-----|-------|----|-----|-------|----
# synchronous|       2.34|        1.00|       131.2|       434.0|  0.43|    0.42|
# 0.47| 17.3|   16.6| 62.7|  7.4|    7.4| 7.5|  7.3|    7.3| 7.4
# ================================================================================
# ===============================================================
#
# Saving benchmarks report...
# Benchmarks report saved to benchmarks.csv
#
# Benchmarking complete.

# %% [markdown]
# # Exploration of the benchmarks.csv file
#
# In the EV column (keep scrolling to the right!) you should see the Mean Time to First Token (TTFT).  This is the average time it took to generate the first token (i.e. process the prompt).
#
# Look in column EY to see how much this varied.
#
# In the EZ column you can see the Total Time for Output Token Mean.  This is the average time it took to generate each token AFTER the prompt was processed and the first token was generated.
#
# Colum FH shows you the Total Output Tokens per Second Mean (which is related to the Time per Output Token).  Column FK shows the variation.  We are only running the tests for 30 seconds, so I think some of the queries get cut off, which is why there are some zeros.

# %% [markdown]
# # Running some tests
#
# Did you wonder why the prompt tokens were set to 125?  Change it to 129 and run it again. (It will overwrite the benchmarks.csv file, but you already have the original copy locally)
#
# You should have originally measured an averate TTFT (Column EV) of 15.6 seconds or so.
#
# After you change to 129, you should see Column EV jump to over 17 seconds.  Why such an increase because of a few tokens?  Buckets!

# %% [markdown]
# # Throughput tests
#
# If you run the cell below against the server you should see a Total Output tokens per second median in column FI (the file name changed!).  If you look in column FJ and FK you can see the standard deviation and outliers.  FH is the mean.  If you needed to rely on these numbers, you should DEFINITELY run the tests longer than 120 seconds because we expect some variability.
#
# # More changes!
#
# Now we are going to experiment with our batch size.  In the other notebook, you are going to push stop (the square) next to the cell, change the configuration to the batch assigned by your instructor on the line that says ```--max-num-seqs=1 \``` and share your results from column FI and FH.
#
# If you are doing this on your own, increase the output_tokens as well as changing the max-num-seqs to numbers from 2-128.

# %%
# !guidellm benchmark \
  --target "http://localhost:8080" \
  --rate-type throughput \
  --max-seconds 120 \
  --data "prompt_tokens=125,output_tokens=120" \
  --output-path=throughput_benchmarks.csv
# Out:
# Creating backend...
# Backend openai_http connected to http://localhost:8080 for model
# TinyLlama/TinyLlama-1.1B-Chat-v1.0.
# Creating request loader...
# Created loader with 1000 unique requests from
# prompt_tokens=125,output_tokens=120.
#
#
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮
# │ [0… th… (r… Req:    0.0 req/s,    0.00s Lat,     1.0 Conc,       0 Comp,   … │
# │             Tok:    0.0 gen/s,    0.0 tot/s,   0.0ms TTFT,    0.0ms ITL,   … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮01:30 ]
# │ [0… th… (r… Req:    0.0 req/s,    0.00s Lat,     9.0 Conc,       0 Comp,   … │
# │             Tok:    0.0 gen/s,    0.0 tot/s,   0.0ms TTFT,    0.0ms ITL,   … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮01:49 ]
# │ [0… th… (r… Req:    0.0 req/s,    0.00s Lat,    19.0 Conc,       0 Comp,   … │
# │             Tok:    0.0 gen/s,    0.0 tot/s,   0.0ms TTFT,    0.0ms ITL,   … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮01:54 ]
# │ [0… th… (r… Req:    0.0 req/s,    0.00s Lat,    82.0 Conc,       0 Comp,   … │
# │             Tok:    0.0 gen/s,    0.0 tot/s,   0.0ms TTFT,    0.0ms ITL,   … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮01:55 ]
# │ [0… th… (r… Req:    0.0 req/s,    0.00s Lat,   155.0 Conc,       0 Comp,   … │
# │             Tok:    0.0 gen/s,    0.0 tot/s,   0.0ms TTFT,    0.0ms ITL,   … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮01:56 ]
# │ [0… th… (r… Req:    0.0 req/s,    0.00s Lat,   247.0 Conc,       0 Comp,   … │
# │             Tok:    0.0 gen/s,    0.0 tot/s,   0.0ms TTFT,    0.0ms ITL,   … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮01:56 ]
# │ [0… th… (r… Req:    0.0 req/s,    0.00s Lat,   334.0 Conc,       0 Comp,   … │
# │             Tok:    0.0 gen/s,    0.0 tot/s,   0.0ms TTFT,    0.0ms ITL,   … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮< 0:01:56 ]
# │ [0… th… (r… Req:    0.0 req/s,    0.00s Lat,   419.0 Conc,       0 Comp,   … │
# │             Tok:    0.0 gen/s,    0.0 tot/s,   0.0ms TTFT,    0.0ms ITL,   … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮< 0:01:56 ]
# │ [0… th… (r… Req:    0.0 req/s,    0.00s Lat,   504.0 Conc,       0 Comp,   … │
# │             Tok:    0.0 gen/s,    0.0 tot/s,   0.0ms TTFT,    0.0ms ITL,   … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮< 0:01:56 ]
# │ [0… th… (r… Req:    0.0 req/s,    0.00s Lat,   512.0 Conc,       0 Comp,   … │
# │             Tok:    0.0 gen/s,    0.0 tot/s,   0.0ms TTFT,    0.0ms ITL,   … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮< 0:01:56 ]
# │ [0… th… (r… Req:    0.0 req/s,    0.00s Lat,   512.0 Conc,       0 Comp,   … │
# │             Tok:    0.0 gen/s,    0.0 tot/s,   0.0ms TTFT,    0.0ms ITL,   … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮< 0:01:56 ]
# │ [0… th… (r… Req:    0.0 req/s,    0.00s Lat,   512.0 Conc,       0 Comp,   … │
# │             Tok:    0.0 gen/s,    0.0 tot/s,   0.0ms TTFT,    0.0ms ITL,   … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮< 0:01:56 ]
# │ [0… th… (r… Req:    0.0 req/s,    0.00s Lat,   512.0 Conc,       0 Comp,   … │
# │             Tok:    0.0 gen/s,    0.0 tot/s,   0.0ms TTFT,    0.0ms ITL,   … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮< 0:01:56 ]
# │ [0… th… (r… Req:    0.0 req/s,    0.00s Lat,   512.0 Conc,       0 Comp,   … │
# │             Tok:    0.0 gen/s,    0.0 tot/s,   0.0ms TTFT,    0.0ms ITL,   … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮< 0:01:56 ]
# │ [0… th… (r… Req:    0.0 req/s,    0.00s Lat,   512.0 Conc,       0 Comp,   … │
# │             Tok:    0.0 gen/s,    0.0 tot/s,   0.0ms TTFT,    0.0ms ITL,   … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮< 0:01:56 ]
# │ [0… th… (r… Req:    0.0 req/s,    0.00s Lat,   512.0 Conc,       0 Comp,   … │
# │             Tok:    0.0 gen/s,    0.0 tot/s,   0.0ms TTFT,    0.0ms ITL,   … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮< 0:01:56 ]
# │ [0… th… (r… Req:    0.0 req/s,    0.00s Lat,   512.0 Conc,       0 Comp,   … │
# │             Tok:    0.0 gen/s,    0.0 tot/s,   0.0ms TTFT,    0.0ms ITL,   … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮< 0:01:56 ]
# │ [0… th… (r… Req:    0.0 req/s,    0.00s Lat,   512.0 Conc,       0 Comp,   … │
# │             Tok:    0.0 gen/s,    0.0 tot/s,   0.0ms TTFT,    0.0ms ITL,   … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮< 0:01:56 ]
# │ [0… th… (r… Req:    0.0 req/s,    0.00s Lat,   512.0 Conc,       0 Comp,   … │
# │             Tok:    0.0 gen/s,    0.0 tot/s,   0.0ms TTFT,    0.0ms ITL,   … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮< 0:01:56 ]
# │ [0… th… (r… Req:    9.8 req/s,    4.57s Lat,   464.0 Conc,      50 Comp,   … │
# │             Tok: 1181.2 gen/s, 2411.6 tot/s, 731.0ms TTFT,   32.2ms ITL,   … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:05 < 0:01:55 ]
# │ [0… th… (r… Req:   21.2 req/s,    4.57s Lat,   457.0 Conc,     113 Comp,   … │
# │             Tok: 2542.4 gen/s, 5190.8 tot/s, 730.9ms TTFT,   32.2ms ITL,   … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:05 < 0:01:54 ]
# │ [0… th… (r… Req:   22.9 req/s,    4.57s Lat,   512.0 Conc,     127 Comp,   … │
# │             Tok: 2750.8 gen/s, 5616.1 tot/s, 732.3ms TTFT,   32.2ms ITL,   … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:05 < 0:01:54 ]
# │ [0… th… (r… Req:   22.9 req/s,    4.57s Lat,   512.0 Conc,     127 Comp,   … │
# │             Tok: 2750.8 gen/s, 5616.1 tot/s, 732.3ms TTFT,   32.2ms ITL,   … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:05 < 0:01:54 ]
# │ [0… th… (r… Req:   22.9 req/s,    4.57s Lat,   512.0 Conc,     127 Comp,   … │
# │             Tok: 2750.8 gen/s, 5616.1 tot/s, 732.3ms TTFT,   32.2ms ITL,   … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:06 < 0:01:54 ]
# │ [0… th… (r… Req:   22.9 req/s,    4.57s Lat,   512.0 Conc,     127 Comp,   … │
# │             Tok: 2750.8 gen/s, 5616.1 tot/s, 732.3ms TTFT,   32.2ms ITL,   … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:06 < 0:01:54 ]
# │ [0… th… (r… Req:   22.9 req/s,    4.57s Lat,   512.0 Conc,     127 Comp,   … │
# │             Tok: 2750.8 gen/s, 5616.1 tot/s, 732.3ms TTFT,   32.2ms ITL,   … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:06 < 0:01:54 ]
# │ [0… th… (r… Req:   22.9 req/s,    4.57s Lat,   512.0 Conc,     127 Comp,   … │
# │             Tok: 2750.8 gen/s, 5616.1 tot/s, 732.3ms TTFT,   32.2ms ITL,   … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:06 < 0:01:54 ]
# │ [0… th… (r… Req:   22.9 req/s,    4.57s Lat,   512.0 Conc,     127 Comp,   … │
# │             Tok: 2750.8 gen/s, 5616.1 tot/s, 732.3ms TTFT,   32.2ms ITL,   … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:07 < 0:01:54 ]
# │ [0… th… (r… Req:   22.9 req/s,    4.57s Lat,   512.0 Conc,     127 Comp,   … │
# │             Tok: 2750.8 gen/s, 5616.1 tot/s, 732.3ms TTFT,   32.2ms ITL,   … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:07 < 0:01:54 ]
# │ [0… th… (r… Req:   22.9 req/s,    4.57s Lat,   512.0 Conc,     127 Comp,   … │
# │             Tok: 2750.8 gen/s, 5616.1 tot/s, 732.3ms TTFT,   32.2ms ITL,   … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:07 < 0:01:54 ]
# │ [0… th… (r… Req:   22.9 req/s,    4.57s Lat,   512.0 Conc,     127 Comp,   … │
# │             Tok: 2750.8 gen/s, 5616.1 tot/s, 732.3ms TTFT,   32.2ms ITL,   … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:07 < 0:01:54 ]
# │ [0… th… (r… Req:   22.9 req/s,    4.57s Lat,   512.0 Conc,     127 Comp,   … │
# │             Tok: 2750.8 gen/s, 5616.1 tot/s, 732.3ms TTFT,   32.2ms ITL,   … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:08 < 0:01:54 ]
# │ [0… th… (r… Req:   22.9 req/s,    4.57s Lat,   512.0 Conc,     127 Comp,   … │
# │             Tok: 2750.8 gen/s, 5616.1 tot/s, 732.3ms TTFT,   32.2ms ITL,   … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:08 < 0:01:54 ]
# │ [0… th… (r… Req:   22.9 req/s,    4.57s Lat,   512.0 Conc,     127 Comp,   … │
# │             Tok: 2750.8 gen/s, 5616.1 tot/s, 732.3ms TTFT,   32.2ms ITL,   … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:08 < 0:01:54 ]
# │ [0… th… (r… Req:   22.9 req/s,    4.57s Lat,   512.0 Conc,     127 Comp,   … │
# │             Tok: 2750.8 gen/s, 5616.1 tot/s, 732.3ms TTFT,   32.2ms ITL,   … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:08 < 0:01:54 ]
# │ [0… th… (r… Req:   22.9 req/s,    4.57s Lat,   512.0 Conc,     127 Comp,   … │
# │             Tok: 2750.8 gen/s, 5616.1 tot/s, 732.3ms TTFT,   32.2ms ITL,   … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:09 < 0:01:54 ]
# │ [0… th… (r… Req:   22.9 req/s,    4.57s Lat,   512.0 Conc,     127 Comp,   … │
# │             Tok: 2750.8 gen/s, 5616.1 tot/s, 732.3ms TTFT,   32.2ms ITL,   … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:09 < 0:01:54 ]
# │ [0… th… (r… Req:   13.5 req/s,    4.64s Lat,   510.0 Conc,     129 Comp,   … │
# │             Tok: 1615.4 gen/s, 3298.1 tot/s, 805.2ms TTFT,   32.2ms ITL,   … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:09 < 0:01:52 ]
# │ [0… th… (r… Req:   23.5 req/s,    6.68s Lat,   418.0 Conc,     233 Comp,   … │
# │             Tok: 2823.2 gen/s, 5764.1 tot/s, 2742.9ms TTFT,   33.0ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:09 < 0:01:50 ]
# │ [0… th… (r… Req:   25.0 req/s,    6.89s Lat,   480.0 Conc,     254 Comp,   … │
# │             Tok: 3000.5 gen/s, 6126.1 tot/s, 2941.1ms TTFT,   33.1ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:10 < 0:01:50 ]
# │ [0… th… (r… Req:   24.8 req/s,    6.89s Lat,   512.0 Conc,     254 Comp,   … │
# │             Tok: 2973.8 gen/s, 6071.4 tot/s, 2941.1ms TTFT,   33.1ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:10 < 0:01:50 ]
# │ [0… th… (r… Req:   24.8 req/s,    6.89s Lat,   512.0 Conc,     254 Comp,   … │
# │             Tok: 2973.8 gen/s, 6071.4 tot/s, 2941.1ms TTFT,   33.1ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:10 < 0:01:50 ]
# │ [0… th… (r… Req:   24.8 req/s,    6.89s Lat,   512.0 Conc,     254 Comp,   … │
# │             Tok: 2973.8 gen/s, 6071.4 tot/s, 2941.1ms TTFT,   33.1ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:10 < 0:01:50 ]
# │ [0… th… (r… Req:   24.8 req/s,    6.89s Lat,   512.0 Conc,     254 Comp,   … │
# │             Tok: 2973.8 gen/s, 6071.4 tot/s, 2941.1ms TTFT,   33.1ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:11 < 0:01:50 ]
# │ [0… th… (r… Req:   24.8 req/s,    6.89s Lat,   512.0 Conc,     254 Comp,   … │
# │             Tok: 2973.8 gen/s, 6071.4 tot/s, 2941.1ms TTFT,   33.1ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:11 < 0:01:50 ]
# │ [0… th… (r… Req:   24.8 req/s,    6.89s Lat,   512.0 Conc,     254 Comp,   … │
# │             Tok: 2973.8 gen/s, 6071.4 tot/s, 2941.1ms TTFT,   33.1ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:11 < 0:01:50 ]
# │ [0… th… (r… Req:   24.8 req/s,    6.89s Lat,   512.0 Conc,     254 Comp,   … │
# │             Tok: 2973.8 gen/s, 6071.4 tot/s, 2941.1ms TTFT,   33.1ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:11 < 0:01:50 ]
# │ [0… th… (r… Req:   24.8 req/s,    6.89s Lat,   512.0 Conc,     254 Comp,   … │
# │             Tok: 2973.8 gen/s, 6071.4 tot/s, 2941.1ms TTFT,   33.1ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:12 < 0:01:50 ]
# │ [0… th… (r… Req:   24.8 req/s,    6.89s Lat,   512.0 Conc,     254 Comp,   … │
# │             Tok: 2973.8 gen/s, 6071.4 tot/s, 2941.1ms TTFT,   33.1ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:12 < 0:01:50 ]
# │ [0… th… (r… Req:   24.8 req/s,    6.89s Lat,   512.0 Conc,     254 Comp,   … │
# │             Tok: 2973.8 gen/s, 6071.4 tot/s, 2941.1ms TTFT,   33.1ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:12 < 0:01:50 ]
# │ [0… th… (r… Req:   24.8 req/s,    6.89s Lat,   512.0 Conc,     254 Comp,   … │
# │             Tok: 2973.8 gen/s, 6071.4 tot/s, 2941.1ms TTFT,   33.1ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:12 < 0:01:50 ]
# │ [0… th… (r… Req:   24.8 req/s,    6.89s Lat,   512.0 Conc,     254 Comp,   … │
# │             Tok: 2973.8 gen/s, 6071.4 tot/s, 2941.1ms TTFT,   33.1ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:13 < 0:01:50 ]
# │ [0… th… (r… Req:   24.8 req/s,    6.89s Lat,   512.0 Conc,     254 Comp,   … │
# │             Tok: 2973.8 gen/s, 6071.4 tot/s, 2941.1ms TTFT,   33.1ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:13 < 0:01:50 ]
# │ [0… th… (r… Req:   24.8 req/s,    6.89s Lat,   512.0 Conc,     254 Comp,   … │
# │             Tok: 2973.8 gen/s, 6071.4 tot/s, 2941.1ms TTFT,   33.1ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:13 < 0:01:50 ]
# │ [0… th… (r… Req:   24.8 req/s,    6.89s Lat,   512.0 Conc,     254 Comp,   … │
# │             Tok: 2973.8 gen/s, 6071.4 tot/s, 2941.1ms TTFT,   33.1ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:13 < 0:01:50 ]
# │ [0… th… (r… Req:   22.0 req/s,    8.14s Lat,   455.0 Conc,     313 Comp,   … │
# │             Tok: 2641.8 gen/s, 5393.6 tot/s, 4225.6ms TTFT,   32.9ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:14 < 0:01:46 ]
# │ [0… th… (r… Req:   26.3 req/s,    9.11s Lat,   439.0 Conc,     381 Comp,   … │
# │             Tok: 3159.3 gen/s, 6450.2 tot/s, 5215.7ms TTFT,   32.7ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:14 < 0:01:46 ]
# │ [0… th… (r… Req:   26.0 req/s,    9.11s Lat,   512.0 Conc,     381 Comp,   … │
# │             Tok: 3115.5 gen/s, 6360.7 tot/s, 5215.7ms TTFT,   32.7ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:14 < 0:01:46 ]
# │ [0… th… (r… Req:   26.0 req/s,    9.11s Lat,   512.0 Conc,     381 Comp,   … │
# │             Tok: 3115.5 gen/s, 6360.7 tot/s, 5215.7ms TTFT,   32.7ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:14 < 0:01:46 ]
# │ [0… th… (r… Req:   26.0 req/s,    9.11s Lat,   512.0 Conc,     381 Comp,   … │
# │             Tok: 3115.5 gen/s, 6360.7 tot/s, 5215.7ms TTFT,   32.7ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:15 < 0:01:46 ]
# │ [0… th… (r… Req:   26.0 req/s,    9.11s Lat,   512.0 Conc,     381 Comp,   … │
# │             Tok: 3115.5 gen/s, 6360.7 tot/s, 5215.7ms TTFT,   32.7ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:15 < 0:01:46 ]
# │ [0… th… (r… Req:   26.0 req/s,    9.11s Lat,   512.0 Conc,     381 Comp,   … │
# │             Tok: 3115.5 gen/s, 6360.7 tot/s, 5215.7ms TTFT,   32.7ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:15 < 0:01:46 ]
# │ [0… th… (r… Req:   26.0 req/s,    9.11s Lat,   512.0 Conc,     381 Comp,   … │
# │             Tok: 3115.5 gen/s, 6360.7 tot/s, 5215.7ms TTFT,   32.7ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:15 < 0:01:46 ]
# │ [0… th… (r… Req:   26.0 req/s,    9.11s Lat,   512.0 Conc,     381 Comp,   … │
# │             Tok: 3115.5 gen/s, 6360.7 tot/s, 5215.7ms TTFT,   32.7ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:16 < 0:01:46 ]
# │ [0… th… (r… Req:   26.0 req/s,    9.11s Lat,   512.0 Conc,     381 Comp,   … │
# │             Tok: 3115.5 gen/s, 6360.7 tot/s, 5215.7ms TTFT,   32.7ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:16 < 0:01:46 ]
# │ [0… th… (r… Req:   26.0 req/s,    9.11s Lat,   512.0 Conc,     381 Comp,   … │
# │             Tok: 3115.5 gen/s, 6360.7 tot/s, 5215.7ms TTFT,   32.7ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:16 < 0:01:46 ]
# │ [0… th… (r… Req:   26.0 req/s,    9.11s Lat,   512.0 Conc,     381 Comp,   … │
# │             Tok: 3115.5 gen/s, 6360.7 tot/s, 5215.7ms TTFT,   32.7ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:17 < 0:01:46 ]
# │ [0… th… (r… Req:   26.0 req/s,    9.11s Lat,   512.0 Conc,     381 Comp,   … │
# │             Tok: 3115.5 gen/s, 6360.7 tot/s, 5215.7ms TTFT,   32.7ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:17 < 0:01:46 ]
# │ [0… th… (r… Req:   26.0 req/s,    9.11s Lat,   512.0 Conc,     381 Comp,   … │
# │             Tok: 3115.5 gen/s, 6360.7 tot/s, 5215.7ms TTFT,   32.7ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:17 < 0:01:46 ]
# │ [0… th… (r… Req:   26.0 req/s,    9.11s Lat,   512.0 Conc,     381 Comp,   … │
# │             Tok: 3115.5 gen/s, 6360.7 tot/s, 5215.7ms TTFT,   32.7ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:17 < 0:01:46 ]
# │ [0… th… (r… Req:   26.0 req/s,    9.11s Lat,   512.0 Conc,     381 Comp,   … │
# │             Tok: 3115.5 gen/s, 6360.7 tot/s, 5215.7ms TTFT,   32.7ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:18 < 0:01:46 ]
# │ [0… th… (r… Req:   26.0 req/s,    9.11s Lat,   512.0 Conc,     381 Comp,   … │
# │             Tok: 3115.5 gen/s, 6360.7 tot/s, 5215.7ms TTFT,   32.7ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:18 < 0:01:46 ]
# │ [0… th… (r… Req:   21.0 req/s,    9.29s Lat,   506.0 Conc,     389 Comp,   … │
# │             Tok: 2519.6 gen/s, 5144.2 tot/s, 5394.4ms TTFT,   32.7ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:18 < 0:01:42 ]
# │ [0… th… (r… Req:   27.0 req/s,   11.29s Lat,   406.0 Conc,     508 Comp,   … │
# │             Tok: 3245.7 gen/s, 6626.7 tot/s, 7432.5ms TTFT,   32.3ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:18 < 0:01:42 ]
# │ [0… th… (r… Req:   26.7 req/s,   11.29s Lat,   497.0 Conc,     508 Comp,   … │
# │             Tok: 3202.5 gen/s, 6538.4 tot/s, 7432.5ms TTFT,   32.3ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:19 < 0:01:41 ]
# │ [0… th… (r… Req:   26.6 req/s,   11.29s Lat,   512.0 Conc,     508 Comp,   … │
# │             Tok: 3195.4 gen/s, 6524.0 tot/s, 7432.5ms TTFT,   32.3ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:19 < 0:01:41 ]
# │ [0… th… (r… Req:   26.6 req/s,   11.29s Lat,   512.0 Conc,     508 Comp,   … │
# │             Tok: 3195.4 gen/s, 6524.0 tot/s, 7432.5ms TTFT,   32.3ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:19 < 0:01:41 ]
# │ [0… th… (r… Req:   26.6 req/s,   11.29s Lat,   512.0 Conc,     508 Comp,   … │
# │             Tok: 3195.4 gen/s, 6524.0 tot/s, 7432.5ms TTFT,   32.3ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:19 < 0:01:41 ]
# │ [0… th… (r… Req:   26.6 req/s,   11.29s Lat,   512.0 Conc,     508 Comp,   … │
# │             Tok: 3195.4 gen/s, 6524.0 tot/s, 7432.5ms TTFT,   32.3ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:20 < 0:01:41 ]
# │ [0… th… (r… Req:   26.6 req/s,   11.29s Lat,   512.0 Conc,     508 Comp,   … │
# │             Tok: 3195.4 gen/s, 6524.0 tot/s, 7432.5ms TTFT,   32.3ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:20 < 0:01:41 ]
# │ [0… th… (r… Req:   26.6 req/s,   11.29s Lat,   512.0 Conc,     508 Comp,   … │
# │             Tok: 3195.4 gen/s, 6524.0 tot/s, 7432.5ms TTFT,   32.3ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:20 < 0:01:41 ]
# │ [0… th… (r… Req:   26.6 req/s,   11.29s Lat,   512.0 Conc,     508 Comp,   … │
# │             Tok: 3195.4 gen/s, 6524.0 tot/s, 7432.5ms TTFT,   32.3ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:20 < 0:01:41 ]
# │ [0… th… (r… Req:   26.6 req/s,   11.29s Lat,   512.0 Conc,     508 Comp,   … │
# │             Tok: 3195.4 gen/s, 6524.0 tot/s, 7432.5ms TTFT,   32.3ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:21 < 0:01:41 ]
# │ [0… th… (r… Req:   26.6 req/s,   11.29s Lat,   512.0 Conc,     508 Comp,   … │
# │             Tok: 3195.4 gen/s, 6524.0 tot/s, 7432.5ms TTFT,   32.3ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:21 < 0:01:41 ]
# │ [0… th… (r… Req:   26.6 req/s,   11.29s Lat,   512.0 Conc,     508 Comp,   … │
# │             Tok: 3195.4 gen/s, 6524.0 tot/s, 7432.5ms TTFT,   32.3ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:21 < 0:01:41 ]
# │ [0… th… (r… Req:   26.6 req/s,   11.29s Lat,   512.0 Conc,     508 Comp,   … │
# │             Tok: 3195.4 gen/s, 6524.0 tot/s, 7432.5ms TTFT,   32.3ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:21 < 0:01:41 ]
# │ [0… th… (r… Req:   26.6 req/s,   11.29s Lat,   512.0 Conc,     508 Comp,   … │
# │             Tok: 3195.4 gen/s, 6524.0 tot/s, 7432.5ms TTFT,   32.3ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:22 < 0:01:41 ]
# │ [0… th… (r… Req:   26.6 req/s,   11.29s Lat,   512.0 Conc,     508 Comp,   … │
# │             Tok: 3195.4 gen/s, 6524.0 tot/s, 7432.5ms TTFT,   32.3ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:22 < 0:01:41 ]
# │ [0… th… (r… Req:   26.6 req/s,   11.29s Lat,   512.0 Conc,     508 Comp,   … │
# │             Tok: 3195.4 gen/s, 6524.0 tot/s, 7432.5ms TTFT,   32.3ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:22 < 0:01:41 ]
# │ [0… th… (r… Req:   26.6 req/s,   11.29s Lat,   512.0 Conc,     508 Comp,   … │
# │             Tok: 3195.4 gen/s, 6524.0 tot/s, 7432.5ms TTFT,   32.3ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:22 < 0:01:41 ]
# │ [0… th… (r… Req:   22.3 req/s,   11.31s Lat,   510.0 Conc,     510 Comp,   … │
# │             Tok: 2674.3 gen/s, 5459.9 tot/s, 7457.7ms TTFT,   32.3ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:23 < 0:01:38 ]
# │ [0… th… (r… Req:   26.4 req/s,   12.48s Lat,   420.0 Conc,     616 Comp,   … │
# │             Tok: 3166.6 gen/s, 6465.1 tot/s, 8635.8ms TTFT,   32.3ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:23 < 0:01:37 ]
# │ [0… th… (r… Req:   26.9 req/s,   12.65s Lat,   482.0 Conc,     635 Comp,   … │
# │             Tok: 3229.3 gen/s, 6593.1 tot/s, 8800.6ms TTFT,   32.3ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:23 < 0:01:37 ]
# │ [0… th… (r… Req:   26.8 req/s,   12.65s Lat,   512.0 Conc,     635 Comp,   … │
# │             Tok: 3218.0 gen/s, 6570.0 tot/s, 8800.6ms TTFT,   32.3ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:23 < 0:01:37 ]
# │ [0… th… (r… Req:   26.8 req/s,   12.65s Lat,   512.0 Conc,     635 Comp,   … │
# │             Tok: 3218.0 gen/s, 6570.0 tot/s, 8800.6ms TTFT,   32.3ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:24 < 0:01:37 ]
# │ [0… th… (r… Req:   26.8 req/s,   12.65s Lat,   512.0 Conc,     635 Comp,   … │
# │             Tok: 3218.0 gen/s, 6570.0 tot/s, 8800.6ms TTFT,   32.3ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:24 < 0:01:37 ]
# │ [0… th… (r… Req:   26.8 req/s,   12.65s Lat,   512.0 Conc,     635 Comp,   … │
# │             Tok: 3218.0 gen/s, 6570.0 tot/s, 8800.6ms TTFT,   32.3ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:24 < 0:01:37 ]
# │ [0… th… (r… Req:   26.8 req/s,   12.65s Lat,   512.0 Conc,     635 Comp,   … │
# │             Tok: 3218.0 gen/s, 6570.0 tot/s, 8800.6ms TTFT,   32.3ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:24 < 0:01:37 ]
# │ [0… th… (r… Req:   26.8 req/s,   12.65s Lat,   512.0 Conc,     635 Comp,   … │
# │             Tok: 3218.0 gen/s, 6570.0 tot/s, 8800.6ms TTFT,   32.3ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:25 < 0:01:37 ]
# │ [0… th… (r… Req:   26.8 req/s,   12.65s Lat,   512.0 Conc,     635 Comp,   … │
# │             Tok: 3218.0 gen/s, 6570.0 tot/s, 8800.6ms TTFT,   32.3ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:25 < 0:01:37 ]
# │ [0… th… (r… Req:   26.8 req/s,   12.65s Lat,   512.0 Conc,     635 Comp,   … │
# │             Tok: 3218.0 gen/s, 6570.0 tot/s, 8800.6ms TTFT,   32.3ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:25 < 0:01:37 ]
# │ [0… th… (r… Req:   26.8 req/s,   12.65s Lat,   512.0 Conc,     635 Comp,   … │
# │             Tok: 3218.0 gen/s, 6570.0 tot/s, 8800.6ms TTFT,   32.3ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:25 < 0:01:37 ]
# │ [0… th… (r… Req:   26.8 req/s,   12.65s Lat,   512.0 Conc,     635 Comp,   … │
# │             Tok: 3218.0 gen/s, 6570.0 tot/s, 8800.6ms TTFT,   32.3ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:26 < 0:01:37 ]
# │ [0… th… (r… Req:   26.8 req/s,   12.65s Lat,   512.0 Conc,     635 Comp,   … │
# │             Tok: 3218.0 gen/s, 6570.0 tot/s, 8800.6ms TTFT,   32.3ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:26 < 0:01:37 ]
# │ [0… th… (r… Req:   26.8 req/s,   12.65s Lat,   512.0 Conc,     635 Comp,   … │
# │             Tok: 3218.0 gen/s, 6570.0 tot/s, 8800.6ms TTFT,   32.3ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:26 < 0:01:37 ]
# │ [0… th… (r… Req:   26.8 req/s,   12.65s Lat,   512.0 Conc,     635 Comp,   … │
# │             Tok: 3218.0 gen/s, 6570.0 tot/s, 8800.6ms TTFT,   32.3ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:26 < 0:01:37 ]
# │ [0… th… (r… Req:   26.8 req/s,   12.65s Lat,   512.0 Conc,     635 Comp,   … │
# │             Tok: 3218.0 gen/s, 6570.0 tot/s, 8800.6ms TTFT,   32.3ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:27 < 0:01:37 ]
# │ [0… th… (r… Req:   26.8 req/s,   12.65s Lat,   512.0 Conc,     635 Comp,   … │
# │             Tok: 3218.0 gen/s, 6570.0 tot/s, 8800.6ms TTFT,   32.3ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:27 < 0:01:37 ]
# │ [0… th… (r… Req:   23.6 req/s,   12.79s Lat,   494.0 Conc,     653 Comp,   … │
# │             Tok: 2833.6 gen/s, 5785.2 tot/s, 8938.0ms TTFT,   32.3ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:27 < 0:01:33 ]
# │ [0… th… (r… Req:   27.3 req/s,   13.54s Lat,   411.0 Conc,     762 Comp,   … │
# │             Tok: 3276.3 gen/s, 6689.1 tot/s, 9673.7ms TTFT,   32.5ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:27 < 0:01:33 ]
# │ [0… th… (r… Req:   27.1 req/s,   13.54s Lat,   501.0 Conc,     762 Comp,   … │
# │             Tok: 3246.9 gen/s, 6629.0 tot/s, 9673.7ms TTFT,   32.5ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:28 < 0:01:32 ]
# │ [0… th… (r… Req:   27.0 req/s,   13.54s Lat,   512.0 Conc,     762 Comp,   … │
# │             Tok: 3243.3 gen/s, 6621.6 tot/s, 9673.7ms TTFT,   32.5ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:28 < 0:01:32 ]
# │ [0… th… (r… Req:   27.0 req/s,   13.54s Lat,   512.0 Conc,     762 Comp,   … │
# │             Tok: 3243.3 gen/s, 6621.6 tot/s, 9673.7ms TTFT,   32.5ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:28 < 0:01:32 ]
# │ [0… th… (r… Req:   27.0 req/s,   13.54s Lat,   512.0 Conc,     762 Comp,   … │
# │             Tok: 3243.3 gen/s, 6621.6 tot/s, 9673.7ms TTFT,   32.5ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:28 < 0:01:32 ]
# │ [0… th… (r… Req:   27.0 req/s,   13.54s Lat,   512.0 Conc,     762 Comp,   … │
# │             Tok: 3243.3 gen/s, 6621.6 tot/s, 9673.7ms TTFT,   32.5ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:29 < 0:01:32 ]
# │ [0… th… (r… Req:   27.0 req/s,   13.54s Lat,   512.0 Conc,     762 Comp,   … │
# │             Tok: 3243.3 gen/s, 6621.6 tot/s, 9673.7ms TTFT,   32.5ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:29 < 0:01:32 ]
# │ [0… th… (r… Req:   27.0 req/s,   13.54s Lat,   512.0 Conc,     762 Comp,   … │
# │             Tok: 3243.3 gen/s, 6621.6 tot/s, 9673.7ms TTFT,   32.5ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:29 < 0:01:32 ]
# │ [0… th… (r… Req:   27.0 req/s,   13.54s Lat,   512.0 Conc,     762 Comp,   … │
# │             Tok: 3243.3 gen/s, 6621.6 tot/s, 9673.7ms TTFT,   32.5ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:29 < 0:01:32 ]
# │ [0… th… (r… Req:   27.0 req/s,   13.54s Lat,   512.0 Conc,     762 Comp,   … │
# │             Tok: 3243.3 gen/s, 6621.6 tot/s, 9673.7ms TTFT,   32.5ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:30 < 0:01:32 ]
# │ [0… th… (r… Req:   27.0 req/s,   13.54s Lat,   512.0 Conc,     762 Comp,   … │
# │             Tok: 3243.3 gen/s, 6621.6 tot/s, 9673.7ms TTFT,   32.5ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:30 < 0:01:32 ]
# │ [0… th… (r… Req:   27.0 req/s,   13.54s Lat,   512.0 Conc,     762 Comp,   … │
# │             Tok: 3243.3 gen/s, 6621.6 tot/s, 9673.7ms TTFT,   32.5ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:30 < 0:01:32 ]
# │ [0… th… (r… Req:   27.0 req/s,   13.54s Lat,   512.0 Conc,     762 Comp,   … │
# │             Tok: 3243.3 gen/s, 6621.6 tot/s, 9673.7ms TTFT,   32.5ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:30 < 0:01:32 ]
# │ [0… th… (r… Req:   27.0 req/s,   13.54s Lat,   512.0 Conc,     762 Comp,   … │
# │             Tok: 3243.3 gen/s, 6621.6 tot/s, 9673.7ms TTFT,   32.5ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:31 < 0:01:32 ]
# │ [0… th… (r… Req:   27.0 req/s,   13.54s Lat,   512.0 Conc,     762 Comp,   … │
# │             Tok: 3243.3 gen/s, 6621.6 tot/s, 9673.7ms TTFT,   32.5ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:31 < 0:01:32 ]
# │ [0… th… (r… Req:   27.0 req/s,   13.54s Lat,   512.0 Conc,     762 Comp,   … │
# │             Tok: 3243.3 gen/s, 6621.6 tot/s, 9673.7ms TTFT,   32.5ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:31 < 0:01:32 ]
# │ [0… th… (r… Req:   23.9 req/s,   13.55s Lat,   511.0 Conc,     763 Comp,   … │
# │             Tok: 2866.7 gen/s, 5852.8 tot/s, 9679.8ms TTFT,   32.5ms ITL,  … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:31 < 0:01:29 ]
# │ [0… th… (r… Req:   26.4 req/s,   14.01s Lat,   431.0 Conc,     851 Comp,   … │
# │             Tok: 3170.0 gen/s, 6472.1 tot/s, 10146.9ms TTFT,   32.4ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:32 < 0:01:28 ]
# │ [0… th… (r… Req:   27.4 req/s,   14.18s Lat,   464.0 Conc,     889 Comp,   … │
# │             Tok: 3285.6 gen/s, 6708.2 tot/s, 10326.5ms TTFT,   32.4ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:32 < 0:01:28 ]
# │ [0… th… (r… Req:   27.3 req/s,   14.18s Lat,   512.0 Conc,     889 Comp,   … │
# │             Tok: 3272.6 gen/s, 6681.5 tot/s, 10326.5ms TTFT,   32.4ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:32 < 0:01:28 ]
# │ [0… th… (r… Req:   27.3 req/s,   14.18s Lat,   512.0 Conc,     889 Comp,   … │
# │             Tok: 3272.6 gen/s, 6681.5 tot/s, 10326.5ms TTFT,   32.4ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:32 < 0:01:28 ]
# │ [0… th… (r… Req:   27.3 req/s,   14.18s Lat,   512.0 Conc,     889 Comp,   … │
# │             Tok: 3272.6 gen/s, 6681.5 tot/s, 10326.5ms TTFT,   32.4ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:33 < 0:01:28 ]
# │ [0… th… (r… Req:   27.3 req/s,   14.18s Lat,   512.0 Conc,     889 Comp,   … │
# │             Tok: 3272.6 gen/s, 6681.5 tot/s, 10326.5ms TTFT,   32.4ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:33 < 0:01:28 ]
# │ [0… th… (r… Req:   27.3 req/s,   14.18s Lat,   512.0 Conc,     889 Comp,   … │
# │             Tok: 3272.6 gen/s, 6681.5 tot/s, 10326.5ms TTFT,   32.4ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:33 < 0:01:28 ]
# │ [0… th… (r… Req:   27.3 req/s,   14.18s Lat,   512.0 Conc,     889 Comp,   … │
# │             Tok: 3272.6 gen/s, 6681.5 tot/s, 10326.5ms TTFT,   32.4ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:33 < 0:01:28 ]
# │ [0… th… (r… Req:   27.3 req/s,   14.18s Lat,   512.0 Conc,     889 Comp,   … │
# │             Tok: 3272.6 gen/s, 6681.5 tot/s, 10326.5ms TTFT,   32.4ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:34 < 0:01:28 ]
# │ [0… th… (r… Req:   27.3 req/s,   14.18s Lat,   512.0 Conc,     889 Comp,   … │
# │             Tok: 3272.6 gen/s, 6681.5 tot/s, 10326.5ms TTFT,   32.4ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:34 < 0:01:28 ]
# │ [0… th… (r… Req:   27.3 req/s,   14.18s Lat,   512.0 Conc,     889 Comp,   … │
# │             Tok: 3272.6 gen/s, 6681.5 tot/s, 10326.5ms TTFT,   32.4ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:34 < 0:01:28 ]
# │ [0… th… (r… Req:   27.3 req/s,   14.18s Lat,   512.0 Conc,     889 Comp,   … │
# │             Tok: 3272.6 gen/s, 6681.5 tot/s, 10326.5ms TTFT,   32.4ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:35 < 0:01:28 ]
# │ [0… th… (r… Req:   27.3 req/s,   14.18s Lat,   512.0 Conc,     889 Comp,   … │
# │             Tok: 3272.6 gen/s, 6681.5 tot/s, 10326.5ms TTFT,   32.4ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮0:35 < 0:01:28 ]
# │ [0… th… (r… Req:   27.3 req/s,   14.18s Lat,   512.0 Conc,     889 Comp,   … │
# │             Tok: 3272.6 gen/s, 6681.5 tot/s, 10326.5ms TTFT,   32.4ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ...
# │ [0… th… (r… Req:   28.0 req/s,   16.96s Lat,   512.0 Conc,    3175 Comp,   … │
# │             Tok: 3357.4 gen/s, 6854.6 tot/s, 13118.5ms TTFT,   32.2ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮1:56 < 0:00:07 ]
# │ [0… th… (r… Req:   28.0 req/s,   16.96s Lat,   512.0 Conc,    3175 Comp,   … │
# │             Tok: 3357.4 gen/s, 6854.6 tot/s, 13118.5ms TTFT,   32.2ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮1:56 < 0:00:07 ]
# │ [0… th… (r… Req:   28.0 req/s,   16.96s Lat,   512.0 Conc,    3175 Comp,   … │
# │             Tok: 3357.4 gen/s, 6854.6 tot/s, 13118.5ms TTFT,   32.2ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮1:56 < 0:00:07 ]
# │ [0… th… (r… Req:   28.0 req/s,   16.96s Lat,   512.0 Conc,    3175 Comp,   … │
# │             Tok: 3357.4 gen/s, 6854.6 tot/s, 13118.5ms TTFT,   32.2ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮1:56 < 0:00:07 ]
# │ [0… th… (r… Req:   27.1 req/s,   16.96s Lat,   511.0 Conc,    3176 Comp,   … │
# │             Tok: 3251.4 gen/s, 6638.2 tot/s, 13119.0ms TTFT,   32.2ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮< 0:00:03 ]
# │ [0… th… (r… Req:   27.8 req/s,   16.99s Lat,   429.0 Conc,    3263 Comp,   … │
# │             Tok: 3332.9 gen/s, 6804.7 tot/s, 13151.3ms TTFT,   32.2ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮< 0:00:03 ]
# │ [0… th… (r… Req:   28.0 req/s,   17.01s Lat,   458.0 Conc,    3302 Comp,   … │
# │             Tok: 3365.5 gen/s, 6871.2 tot/s, 13167.5ms TTFT,   32.2ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮< 0:00:03 ]
# │ [0… th… (r… Req:   28.0 req/s,   17.01s Lat,   512.0 Conc,    3302 Comp,   … │
# │             Tok: 3361.1 gen/s, 6862.2 tot/s, 13167.5ms TTFT,   32.2ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮< 0:00:03 ]
# │ [0… th… (r… Req:   28.0 req/s,   17.01s Lat,   512.0 Conc,    3302 Comp,   … │
# │             Tok: 3361.1 gen/s, 6862.2 tot/s, 13167.5ms TTFT,   32.2ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮< 0:00:03 ]
# │ [0… th… (r… Req:   28.0 req/s,   17.01s Lat,   512.0 Conc,    3302 Comp,   … │
# │             Tok: 3361.1 gen/s, 6862.2 tot/s, 13167.5ms TTFT,   32.2ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮< 0:00:03 ]
# │ [0… th… (r… Req:   28.0 req/s,   17.01s Lat,   512.0 Conc,    3302 Comp,   … │
# │             Tok: 3361.1 gen/s, 6862.2 tot/s, 13167.5ms TTFT,   32.2ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮< 0:00:03 ]
# │ [0… th… (r… Req:   28.0 req/s,   17.01s Lat,   512.0 Conc,    3302 Comp,   … │
# │             Tok: 3361.1 gen/s, 6862.2 tot/s, 13167.5ms TTFT,   32.2ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮< 0:00:03 ]
# │ [0… th… (r… Req:   28.0 req/s,   17.01s Lat,   512.0 Conc,    3302 Comp,   … │
# │             Tok: 3361.1 gen/s, 6862.2 tot/s, 13167.5ms TTFT,   32.2ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮< 0:00:03 ]
# │ [0… th… (r… Req:   28.0 req/s,   17.01s Lat,   512.0 Conc,    3302 Comp,   … │
# │             Tok: 3361.1 gen/s, 6862.2 tot/s, 13167.5ms TTFT,   32.2ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮< 0:00:03 ]
# │ [0… th… (r… Req:   28.0 req/s,   17.01s Lat,   512.0 Conc,    3302 Comp,   … │
# │             Tok: 3361.1 gen/s, 6862.2 tot/s, 13167.5ms TTFT,   32.2ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮< 0:00:03 ]
# │ [0… th… (r… Req:   28.0 req/s,   17.01s Lat,   512.0 Conc,    3302 Comp,   … │
# │             Tok: 3361.1 gen/s, 6862.2 tot/s, 13167.5ms TTFT,   32.2ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮< 0:00:03 ]
# │ [0… th… (r… Req:   27.5 req/s,   16.98s Lat,   500.0 Conc,    3302 Comp,   … │
# │             Tok: 3306.5 gen/s, 6750.7 tot/s, 13169.0ms TTFT,   32.2ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮00:00 ]
# │ [0… th… (r… Req:   27.4 req/s,   16.76s Lat,   403.0 Conc,    3302 Comp,   … │
# │             Tok: 3396.1 gen/s, 6933.6 tot/s, 13177.5ms TTFT,   32.4ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮00:00 ]
# │ [0… th… (r… Req:   27.3 req/s,   16.43s Lat,   233.0 Conc,    3302 Comp,   … │
# │             Tok: 3557.8 gen/s, 7263.9 tot/s, 13192.9ms TTFT,   32.6ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮00:00 ]
# │ [0… th… (r… Req:   27.3 req/s,   16.13s Lat,    66.0 Conc,    3302 Comp,   … │
# │             Tok: 3715.0 gen/s, 7584.7 tot/s, 13202.9ms TTFT,   32.8ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮00:00 ]
# │ [0… th… (r… Req:   27.2 req/s,   16.03s Lat,     2.0 Conc,    3302 Comp,   … │
# │             Tok: 3773.5 gen/s, 7704.3 tot/s, 13207.7ms TTFT,   32.9ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮00:00 ]
# │ [0… th… (r… Req:   27.2 req/s,   16.03s Lat,     0.0 Conc,    3302 Comp,   … │
# │             Tok: 3765.6 gen/s, 7688.2 tot/s, 13207.7ms TTFT,   32.9ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮00:00 ]
# │ [0… th… (r… Req:   27.1 req/s,   16.03s Lat,     1.0 Conc,    3302 Comp,   … │
# │             Tok: 3757.8 gen/s, 7672.2 tot/s, 13207.7ms TTFT,   32.9ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮00:00 ]
# │ [0… th… (r… Req:   27.1 req/s,   16.03s Lat,     1.0 Conc,    3302 Comp,   … │
# │             Tok: 3750.0 gen/s, 7656.4 tot/s, 13207.7ms TTFT,   32.9ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮00:00 ]
# │ [0… th… (r… Req:   27.0 req/s,   16.03s Lat,     0.0 Conc,    3302 Comp,   … │
# │             Tok: 3742.3 gen/s, 7640.5 tot/s, 13207.7ms TTFT,   32.9ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮00:00 ]
# │ [0… th… (r… Req:   26.9 req/s,   16.03s Lat,     0.0 Conc,    3302 Comp,   … │
# │             Tok: 3734.5 gen/s, 7624.7 tot/s, 13207.7ms TTFT,   32.9ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮00:00 ]
# │ [0… th… (r… Req:   26.9 req/s,   16.03s Lat,     0.0 Conc,    3302 Comp,   … │
# │             Tok: 3726.9 gen/s, 7609.0 tot/s, 13207.7ms TTFT,   32.9ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮00:00 ]
# │ [0… th… (r… Req:   26.8 req/s,   16.03s Lat,     0.0 Conc,    3302 Comp,   … │
# │             Tok: 3719.2 gen/s, 7593.4 tot/s, 13207.7ms TTFT,   32.9ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮00:00 ]
# │ [0… th… (co… Req:   26.8 req/s,   16.03s Lat,     0.0 Conc,    3302 Comp,  … │
# │              Tok: 3715.0 gen/s, 7584.7 tot/s, 13207.7ms TTFT,   32.9ms ITL,… │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮00:00 ]
# │ [0… th… (co… Req:   26.8 req/s,   16.03s Lat,     0.0 Conc,    3302 Comp,  … │
# │              Tok: 3715.0 gen/s, 7584.7 tot/s, 13207.7ms TTFT,   32.9ms ITL,… │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮00:00 ]
# │ [0… th… (co… Req:   26.8 req/s,   16.03s Lat,     0.0 Conc,    3302 Comp,  … │
# │              Tok: 3715.0 gen/s, 7584.7 tot/s, 13207.7ms TTFT,   32.9ms ITL,… │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮00:00 ]
# │ [0… th… (co… Req:   26.8 req/s,   16.03s Lat,     0.0 Conc,    3302 Comp,  … │
# │              Tok: 3715.0 gen/s, 7584.7 tot/s, 13207.7ms TTFT,   32.9ms ITL,… │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮00:00 ]
# │ [0… th… (co… Req:   26.8 req/s,   16.03s Lat,     0.0 Conc,    3302 Comp,  … │
# │              Tok: 3715.0 gen/s, 7584.7 tot/s, 13207.7ms TTFT,   32.9ms ITL,… │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮00:00 ]
# │ [0… th… (co… Req:   26.8 req/s,   16.03s Lat,     0.0 Conc,    3302 Comp,  … │
# │              Tok: 3715.0 gen/s, 7584.7 tot/s, 13207.7ms TTFT,   32.9ms ITL,… │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮00:00 ]
# │ [0… th… (co… Req:   26.8 req/s,   16.03s Lat,     0.0 Conc,    3302 Comp,  … │
# │              Tok: 3715.0 gen/s, 7584.7 tot/s, 13207.7ms TTFT,   32.9ms ITL,… │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮00:00 ]
# │ [0… th… (co… Req:   26.8 req/s,   16.03s Lat,     0.0 Conc,    3302 Comp,  … │
# │              Tok: 3715.0 gen/s, 7584.7 tot/s, 13207.7ms TTFT,   32.9ms ITL,… │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮00:00 ]
# │ [0… th… (co… Req:   26.8 req/s,   16.03s Lat,     0.0 Conc,    3302 Comp,  … │
# │              Tok: 3715.0 gen/s, 7584.7 tot/s, 13207.7ms TTFT,   32.9ms ITL,… │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Benchmarks ─────────────────────────────────────────────────────────────────╮00:00 ]
# │ [0… th… (c… Req:   28.2 req/s,   17.00s Lat,   479.6 Conc,    3302 Comp,   … │
# │             Tok: 3385.1 gen/s, 6916.3 tot/s, 13167.5ms TTFT,   32.2ms ITL, … │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# Generating... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ (1/1) [ 0:02:00 < 0:00:00 ]
#
#
# Benchmarks Metadata:
#     Run id:c8379d8f-32e8-483d-9874-7ceba486b08b
#     Duration:123.3 seconds
#     Profile:type=throughput, strategies=['throughput'], max_concurrency=None
#     Args:max_number=None, max_duration=120.0, warmup_number=None,
#     warmup_duration=None, cooldown_number=None, cooldown_duration=None
#     Worker:type_='generative_requests_worker' backend_type='openai_http'
#     backend_target='http://localhost:8080'
#     backend_model='TinyLlama/TinyLlama-1.1B-Chat-v1.0'
#     backend_info={'max_output_tokens': 16384, 'timeout': 300, 'http2': True,
#     'follow_redirects': True, 'headers': {}, 'text_completions_path':
#     '/v1/completions', 'chat_completions_path': '/v1/chat/completions'}
#     Request Loader:type_='generative_request_loader'
#     data='prompt_tokens=125,output_tokens=120' data_args=None
#     processor='TinyLlama/TinyLlama-1.1B-Chat-v1.0' processor_args=None
#     Extras:None
#
#
# Benchmarks Info:
# ================================================================================
# ===============================================================
# Metadata                                   |||| Requests Made  ||| Prompt
# Tok/Req ||| Output Tok/Req ||| Prompt Tok Total||| Output Tok Total||
#  Benchmark| Start Time| End Time| Duration (s)|  Comp|  Inc|  Err|  Comp|   Inc|
# Err|  Comp|   Inc| Err|   Comp|   Inc| Err|   Comp|   Inc| Err
# ----------|-----------|---------|-------------|------|-----|-----|------|------|
# ----|------|------|----|-------|------|----|-------|------|----
# throughput|   01:19:33| 01:21:33|        120.0|  3302|  512|    0| 126.2| 125.0|
# 0.0| 120.0| 106.1| 0.0| 416629| 64000|   0| 396240| 54340|   0
# ================================================================================
# ===============================================================
#
#
# Benchmarks Stats:
# ================================================================================
# ======================================================================
# Metadata  | Request Stats         || Out Tok/sec| Tot Tok/sec| Req Latency (sec)
# ||| TTFT (ms)              ||| ITL (ms)        ||| TPOT (ms)       ||
#  Benchmark| Per Second| Concurrency|        mean|        mean|  mean| median|
# p99|    mean|  median|     p99| mean| median|  p99| mean| median|  p99
# ----------|-----------|------------|------------|------------|------|-------|---
# ---|--------|--------|--------|-----|-------|-----|-----|-------|-----
# throughput|      28.21|      479.63|      3385.1|      6916.3| 17.00|  17.88|
# 22.34| 13167.5| 14043.1| 17998.0| 32.2|   32.1| 38.1| 31.9|   31.8| 37.8
# ================================================================================
# ======================================================================
#
# Saving benchmarks report...
# Benchmarks report saved to throughput_benchmarks.csv
#
# Benchmarking complete.
